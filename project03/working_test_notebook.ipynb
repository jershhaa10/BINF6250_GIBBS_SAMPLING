# %%
import random
import numpy as np
from math import log, sqrt
import bamnostic
import seqlogo as sl
import pandas as pd
# Out:
#  UserWarning:/home/linh/miniconda3/envs/gibbs/lib/python3.14/site-packages/weblogo/__init__.py:1: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.

# %%
BASES = ("A", "C", "G", "T")
BASE_INDEX = {"A": 0, "C": 1, "G": 2, "T": 3}

# %%
### get reads ###

# from seq_ops
COMP_TRANS = str.maketrans('ACGTacgt', 'TGCAtcga')
def reverse_complement(seq):
    """Get the reverse complement of a nucleotide sequence

    Returns the reverse complement of the input string representing a DNA 
    sequence. Works only with DNA sequences consisting solely of  A, C, G, T or N 
    characters. Preserves the case of the input sequence.

    Args:
        seq (str): a DNA sequence string

    Returns:
        (str): The reverse complement of the input DNA sequence string.
    """

    # Translate then reverse seq
    return seq.translate(COMP_TRANS)[::-1]

# reservoir sampling from bam
def get_reads_from_bam(bam_path, n, seed=None):
    rng = random.Random(seed)
    bam = bamnostic.AlignmentFile(bam_path, "rb")

    reservoir = []
    seen = 0  # number of reads seen so far

    for read in bam:
        if getattr(read, "is_unmapped", True) or getattr(read, "is_secondary", True) or \
           getattr(read, "is_supplementary", True):
            continue
        seq = getattr(read, "query_sequence", None)
        if getattr(read, "is_reverse", False):
            seq = reverse_complement(seq)
        seen += 1
        if len(reservoir) < n:
            reservoir.append(seq)
        else:
            j = rng.randrange(seen)
            if j < n:
                reservoir[j] = seq

    bam.close()

    print(f"successfully retrieved {len(reservoir)} reads from bam file.")
    return reservoir

# %%
### random small helpers ###
def add_kmer_to_pfm(pfm: np.ndarray, kmer: str, sign: int) -> None:
    """
    in-place add (sign=+1) or remove (sign=-1) a k-mer from PFM.
    """
    for j, ch in enumerate(kmer):
        pfm[BASE_INDEX[ch], j] += sign

def frobenius_norm(mat: np.ndarray) -> float:
    return sqrt(float(np.sum(mat * mat)))

def is_valid_kmer(seq): # boolean helper 
    return all(ch in BASE_INDEX for ch in seq)

# %%
### 0th-order bg model ###
def build_markov_0th_order(reads: list, pseudocount: float) -> dict:
    '''
    input: list of reads and background pseudocount
    returns a dict like {"A":pA,"C":pC,"G":pG,"T":pT}
    '''

    if pseudocount <= 0:
        raise ValueError("pseudocount must be > 0")

    a = c = g = t = 0

    for read in reads:
        if not read:
            continue
        r = read.upper()

        a += r.count("A")
        c += r.count("C")
        g += r.count("G")
        t += r.count("T")

    total = (a + c + g + t) + pseudocount * 4

    return {
        "A": (a + pseudocount) / total,
        "C": (c + pseudocount) / total,
        "G": (g + pseudocount) / total,
        "T": (t + pseudocount) / total,
    }

# %%
### matrix stuff ###

def build_pfm(sequences, length) -> np.ndarray:
    # like build_pfm from motif_ops but doesn't silently turn invalid characters into As
    pfm = np.zeros((4, length), dtype=np.int32)

    # one slot for every possible byte value, all initially -1
    base_to_index = np.full(256, -1, dtype=np.int16)
    base_to_index[ord('A')] = 0
    base_to_index[ord('C')] = 1
    base_to_index[ord('G')] = 2
    base_to_index[ord('T')] = 3

    cols = np.arange(length)

    for seq in sequences:
        seq_array = np.frombuffer(seq[:length].encode(), dtype=np.uint8)
        indices = base_to_index[seq_array]

        # only count valid A/C/G/T
        mask = indices >= 0
        np.add.at(pfm, (indices[mask], cols[mask]), 1)

    return pfm

def build_pwm(pfm, bg, pseudocount) -> np.ndarray:
    """
    PWM[b,j] = log2( P_motif(b|j) / P_bg(b) )
    pfm: (4, k) counts
    bg: dict like {"A":pA,"C":pC,"G":pG,"T":pT}
    """

    # like build_pwm from motif_ops but the background probs arent hardcoded
    # this format also only works for 0th order background models

    # bg (4, 1), it's a column vector in A,C,G,T order
    bg_vec = np.array([bg[b] for b in BASES], dtype=float).reshape(4, 1)

    # column sums (1, k)
    sums = pfm.sum(axis=0, keepdims=True) + 4 * pseudocount

    # motif probabilities (4, k)
    p_motif = (pfm.astype(float) + pseudocount) / sums

    # log-odds vs background
    pwm = np.log2(p_motif) - np.log2(bg_vec)

    return pwm

## diagnostics ##
TRANS_TAB = str.maketrans('ACGT', '0123')
def score_kmer(seq: str, pwm: np.ndarray) -> float:
    # this is as it is in motif_ops
    """
    Score a k-mer using a Position Weight Matrix (PWM).

    The k-mer length is expected to be the same as the PWM length.

    Args:
        seq (str): k-mer to score.
        pwm (np.ndarray): PWM for scoring.

    Returns:
        float: PWM score for the k-mer.

    Raises:
        ValueError: If the k-mer and PWM are different lengths.
    """
    if len(seq) != len(pwm[0]):
        raise ValueError('K-mer and PWM are different lengths!')

    indices = np.fromiter((int(nt) for nt in seq.translate(TRANS_TAB)), dtype = int)
    return np.sum(pwm[indices, np.arange(len(indices))])

def pfm_ic(pfm: np.ndarray, p) -> float:
    #like pfm_ic in motif_ops, but motif pseudocount is parameterized
    sums = np.sum(pfm, axis=0) + 4 * p
    fij = (pfm + p) / sums
    ic = np.sum(2 + np.sum(fij * np.log2(fij), axis=0, where=fij > 0))
    return ic

# %%
### initiation function ###

def init_sites_and_matrices(reads, k, bg, seed, max_tries, pseudocount) -> \
    (list[int], list[str], np.ndarray, np.ndarray):
    """
    initiation:
    - choose random start positions for each read
    - build initial PFM/PWM from chosen k-mers

    input: reads, k, bg, seed, max tries (for choosing initial motif windows), motif pseudocount
    output: starts, candidates, pfm (integers), pwm (floats)
    """
    rng = random.Random(seed)

    starts = []
    candidates = []

    for read in reads:
        read=read.upper()
        L = len(read)
        if L < k:
            raise ValueError("all reads must have length >= k")
        
        for _ in range(max_tries):
            start = rng.randrange(0, L - k + 1)
            kmer = read[start:start + k]
            if is_valid_kmer(kmer):
                starts.append(start)
                candidates.append(kmer)
                break 
        else:
            raise ValueError("could not sample a valid initial k-mer from read")
        

    pfm = build_pfm(candidates, k)
    pwm = build_pwm(pfm, bg, pseudocount=pseudocount)

    return starts, candidates, pfm, pwm

# %%
############# ONE GIBBS UPDATE ##############

LN2 = log(2.0)

def gibbs_update(
    reads: list[str], starts: list[int], pfm: np.ndarray,
    i: int, k: int, bg: dict, 
    motif_pseudocount: float, 
    rng: random.Random, 
    max_tries: int = 50 ) -> int:
    '''
    performs one gibbs move updating read i.
    
    effects are:
        changes start[i].
        changes pfm.
    
    returns the newly sampled start index for the read. 
    '''

    read = reads[i].upper() # identify the read
    L = len(read)

    if L < k:
        raise ValueError("Read length < k")

    # identify current start position
    old_start = starts[i]

    # identify current candidate motif
    old_kmer = read[old_start:old_start + k]

    # uncount kmer in pfm
    add_kmer_to_pfm(pfm, old_kmer, sign=-1)

    # leave-one-out PWM 
    loo_pwm = build_pwm(pfm, bg, pseudocount=motif_pseudocount)

    # number of starts to score
    n_starts = L - k + 1

    # initialize scores array and validity mask
    scores = np.zeros(n_starts, dtype=float) 
    valid = np.zeros(n_starts, dtype=bool) 

    # score each start to create a probability distribution
    for start in range(n_starts):

        kmer = read[start:start + k]

        if is_valid_kmer(kmer):
            valid[start] = True
            scores[start] = score_kmer(kmer, loo_pwm)
            # scores = log2(P(kmer|motif)/P(kmer|bg))
        else:
            continue

    valid_windows = np.flatnonzero(valid)
    if valid_windows.size == 0:
        # no valid windows; restore old k-mer if we removed it and keep start unchanged
        # defensive programming. init already found a valid window
        if is_valid_kmer(old_kmer):
            add_kmer_to_pfm(pfm, old_kmer, sign=+1) # put everything back
        return old_start

    #convert to weights
    m = float(np.max(scores[valid_windows])) # max score found
    w = np.zeros_like(scores) # initialize scores vector; the invalid windows will keep weight 0

    w[valid] = np.exp((scores[valid] - m) * LN2) # 2^x=(e^(ln2))^x=e^(xln2)
    # with x = score - max score, we keep weights between 0 and 1
    # the max scoring window has weight 2^x = 2^0 = 1, for everything else x is negative so 2^x is between 0 and 1
    # ie. cannot overflow and also makes debugging easier if it comes up

    # random choice
    # choices() wants lists
    population = valid_windows.tolist() 
    w_list = w[valid].tolist()

    # choose new start probabilisitically
    new_start = rng.choices(population, weights=w_list, k=1)[0]

    # count new motif candidate in pfm
    new_kmer = read[new_start:new_start + k]
    add_kmer_to_pfm(pfm, new_kmer, sign=+1)
    starts[i] = new_start

    # print(f"""
    # read n. {i}:
    # start position {old_start} -> {new_start}
    # """)

    return new_start

# %%
##### ALGORITHM WRAPPER #####

def GibbsMotifSampler(
    seqs: list[str], k: int, seed: int = 123,
    bg_pseudocount: float = 1.0, motif_pseudocount: float = 0.25,
    max_tries_init: int = 50, 
    burn_in_sweeps: int = 1,
    check_every_sweeps: int = 10,
    rel_thresh: float = 0.001,
    max_sweeps: int = 100
    ) -> np.ndarray:

    if k <= 0:
        raise ValueError("k must be > 0")
    if not seqs:
        raise ValueError("seqs must be non-empty")

    # 0th order iid
    bg = build_markov_0th_order(seqs, bg_pseudocount)

    ###### INITIATION ##########
    rng = random.Random(seed)
    starts, candidates, pfm, pwm = \
        init_sites_and_matrices(
            seqs, k, bg, seed=seed, max_tries=max_tries_init, pseudocount=motif_pseudocount
            )
    
    print("burning in...")
    prev_pwm = None
    n = len(seqs)
    ######### ITERATION ###########
    for sweep in range(1, max_sweeps + 1):
        # one sweep = n single updates
        
        for _ in range(n):
            i = rng.randrange(0, len(seqs))
            gibbs_update(seqs, starts, pfm, i, k, bg, motif_pseudocount, rng)

        if sweep <= burn_in_sweeps: # are we still in burn-in
            continue
        if sweep == (burn_in_sweeps+1):
            print("..done burning in...")
        if (sweep - burn_in_sweeps) % check_every_sweeps != 0: # is it not checking time
            continue


        #### CHECK CONVERGENCE #####
        pwm_now = build_pwm(pfm, bg, pseudocount=motif_pseudocount)

        if prev_pwm is None:
            prev_pwm = pwm_now
            continue

        diff = pwm_now - prev_pwm

        num = frobenius_norm(diff)
        den = frobenius_norm(prev_pwm)
        rel = num / den if den > 0 else float("inf")

        prev_pwm = pwm_now
        ic = pfm_ic(pfm,motif_pseudocount)
        print(f"""
        {sweep} sweeps complete,
        IC = {ic:3f},
        relative Frobenius diff = {rel:3f}
        """)

        if rel < rel_thresh:
            break

    return pfm

# %%
seed=123

seqs = get_reads_from_bam("data/SRR9090854.subsampled_5pct.bam",100,seed=seed)

pfm = GibbsMotifSampler(
    seqs=seqs, 
    k = 9, seed = seed,
    bg_pseudocount = 1.0, 
    motif_pseudocount = 0.25,
    max_tries_init = 10, 
    burn_in_sweeps = 10,
    check_every_sweeps = 10,
    rel_thresh = 0.01,
    max_sweeps = 1000
    )

sl.Pfm(pfm)

sl.seqlogo(sl.CompletePm(pfm = pfm.T))
# Out:
# successfully retrieved 100 reads from bam file.
# burning in...
# ..done burning in...
#
#         30 sweeps complete,
#         IC = 3.841516,
#         relative Frobenius diff = 0.310204
#
#
#         40 sweeps complete,
#         IC = 3.651444,
#         relative Frobenius diff = 0.373128
#
#
#         50 sweeps complete,
#         IC = 3.831212,
#         relative Frobenius diff = 0.478812
#
#
#         60 sweeps complete,
#         IC = 3.396832,
#         relative Frobenius diff = 0.411640
#
#
#         70 sweeps complete,
#         IC = 3.621918,
#         relative Frobenius diff = 0.398835
#
#
#         80 sweeps complete,
#         IC = 3.501728,
#         relative Frobenius diff = 0.486905
#
#
#         90 sweeps complete,
#         IC = 3.640949,
#         relative Frobenius diff = 0.438374
#
#
#         100 sweeps complete,
#         IC = 3.314852,
#         relative Frobenius diff = 0.520514
#
#
#         110 sweeps complete,
#         IC = 3.425711,
#         relative Frobenius diff = 0.751460
#
#
#         120 sweeps complete,
#         IC = 3.498442,
#         relative Frobenius diff = 0.319176
#
#
#         130 sweeps complete,
#         IC = 3.431075,
#         relative Frobenius diff = 0.370527
#
#
#         140 sweeps complete,
#         IC = 3.208580,
#         relative Frobenius diff = 0.447652
#
#
#         150 sweeps complete,
#         IC = 3.129712,
#         relative Frobenius diff = 0.594797
#
#
#         160 sweeps complete,
#         IC = 3.521517,
#         relative Frobenius diff = 0.415735
#
#
#         170 sweeps complete,
#         IC = 3.399121,
#         relative Frobenius diff = 0.856699
#
#
#         180 sweeps complete,
#         IC = 3.572115,
#         relative Frobenius diff = 0.655026
#
#
#         190 sweeps complete,
#         IC = 3.149541,
#         relative Frobenius diff = 0.606977
#
#
#         200 sweeps complete,
#         IC = 3.807528,
#         relative Frobenius diff = 0.775646
#
#
#         210 sweeps complete,
#         IC = 3.613065,
#         relative Frobenius diff = 0.646454
#
#
#         220 sweeps complete,
#         IC = 2.978380,
#         relative Frobenius diff = 0.636205
#
#
#         230 sweeps complete,
#         IC = 3.872497,
#         relative Frobenius diff = 0.398837
#
#
#         240 sweeps complete,
#         IC = 3.646939,
#         relative Frobenius diff = 0.566492
#
#
#         250 sweeps complete,
#         IC = 3.568834,
#         relative Frobenius diff = 0.475451
#
#
#         260 sweeps complete,
#         IC = 3.530269,
#         relative Frobenius diff = 0.425508
#
#
#         270 sweeps complete,
#         IC = 3.469765,
#         relative Frobenius diff = 0.477529
#
#
#         280 sweeps complete,
#         IC = 3.654279,
#         relative Frobenius diff = 0.538375
#
#
#         290 sweeps complete,
#         IC = 3.506337,
#         relative Frobenius diff = 0.333194
#
#
#         300 sweeps complete,
#         IC = 3.336988,
#         relative Frobenius diff = 0.662718
#
#
#         310 sweeps complete,
#         IC = 3.331242,
#         relative Frobenius diff = 0.249360
#
#
#         320 sweeps complete,
#         IC = 3.693165,
#         relative Frobenius diff = 0.563932
#
#
#         330 sweeps complete,
#         IC = 3.355698,
#         relative Frobenius diff = 0.579565
#
#
#         340 sweeps complete,
#         IC = 3.524925,
#         relative Frobenius diff = 0.849786
#
#
#         350 sweeps complete,
#         IC = 3.359552,
#         relative Frobenius diff = 0.495707
#
#
#         360 sweeps complete,
#         IC = 3.611465,
#         relative Frobenius diff = 0.431346
#
#
#         370 sweeps complete,
#         IC = 3.300213,
#         relative Frobenius diff = 0.748390
#
#
#         380 sweeps complete,
#         IC = 3.384192,
#         relative Frobenius diff = 0.720530
#
#
#         390 sweeps complete,
#         IC = 3.287447,
#         relative Frobenius diff = 0.549100
#
#
#         400 sweeps complete,
#         IC = 3.479823,
#         relative Frobenius diff = 0.824910
#
#
#         410 sweeps complete,
#         IC = 3.093615,
#         relative Frobenius diff = 0.556414
#
#
#         420 sweeps complete,
#         IC = 2.978940,
#         relative Frobenius diff = 0.716746
#
#
#         430 sweeps complete,
#         IC = 3.347383,
#         relative Frobenius diff = 0.969566
#
#
#         440 sweeps complete,
#         IC = 3.549913,
#         relative Frobenius diff = 0.556514
#
#
#         450 sweeps complete,
#         IC = 3.105241,
#         relative Frobenius diff = 0.721507
#
#
#         460 sweeps complete,
#         IC = 3.246650,
#         relative Frobenius diff = 0.690937
#
#
#         470 sweeps complete,
#         IC = 3.482515,
#         relative Frobenius diff = 0.599104
#
#
#         480 sweeps complete,
#         IC = 3.512978,
#         relative Frobenius diff = 0.593036
#
#
#         490 sweeps complete,
#         IC = 3.470955,
#         relative Frobenius diff = 0.573266
#
#
#         500 sweeps complete,
#         IC = 3.444682,
#         relative Frobenius diff = 0.439227
#
#
#         510 sweeps complete,
#         IC = 3.564350,
#         relative Frobenius diff = 0.859754
#
#
#         520 sweeps complete,
#         IC = 3.846595,
#         relative Frobenius diff = 0.539987
#
#
#         530 sweeps complete,
#         IC = 3.866355,
#         relative Frobenius diff = 0.353079
#
#
#         540 sweeps complete,
#         IC = 3.617011,
#         relative Frobenius diff = 0.417788
#
#
#         550 sweeps complete,
#         IC = 3.592051,
#         relative Frobenius diff = 0.574322
#
#
#         560 sweeps complete,
#         IC = 3.353411,
#         relative Frobenius diff = 0.604606
#
#
#         570 sweeps complete,
#         IC = 3.377027,
#         relative Frobenius diff = 0.531596
#
#
#         580 sweeps complete,
#         IC = 3.554429,
#         relative Frobenius diff = 0.737284
#
#
#         590 sweeps complete,
#         IC = 3.383457,
#         relative Frobenius diff = 0.314093
#
#
#         600 sweeps complete,
#         IC = 3.090163,
#         relative Frobenius diff = 0.539448
#
#
#         610 sweeps complete,
#         IC = 3.459456,
#         relative Frobenius diff = 0.751875
#
#
#         620 sweeps complete,
#         IC = 3.452643,
#         relative Frobenius diff = 0.400341
#
#
#         630 sweeps complete,
#         IC = 3.719402,
#         relative Frobenius diff = 0.592169
#
#
#         640 sweeps complete,
#         IC = 3.469838,
#         relative Frobenius diff = 0.465827
#
#
#         650 sweeps complete,
#         IC = 3.476164,
#         relative Frobenius diff = 0.525899
#
#
#         660 sweeps complete,
#         IC = 3.256011,
#         relative Frobenius diff = 0.564966
#
#
#         670 sweeps complete,
#         IC = 3.296933,
#         relative Frobenius diff = 0.768576
#
#
#         680 sweeps complete,
#         IC = 3.733824,
#         relative Frobenius diff = 0.552769
#
#
#         690 sweeps complete,
#         IC = 3.836142,
#         relative Frobenius diff = 0.970136
#
#
#         700 sweeps complete,
#         IC = 3.428078,
#         relative Frobenius diff = 0.637593
#
#
#         710 sweeps complete,
#         IC = 3.570182,
#         relative Frobenius diff = 0.922705
#
#
#         720 sweeps complete,
#         IC = 3.461064,
#         relative Frobenius diff = 0.872003
#
#
#         730 sweeps complete,
#         IC = 3.650618,
#         relative Frobenius diff = 0.675906
#
#
#         740 sweeps complete,
#         IC = 3.247314,
#         relative Frobenius diff = 0.768847
#
#
#         750 sweeps complete,
#         IC = 3.964646,
#         relative Frobenius diff = 0.897268
#
#
#         760 sweeps complete,
#         IC = 3.483048,
#         relative Frobenius diff = 0.633696
#
#
#         770 sweeps complete,
#         IC = 3.540379,
#         relative Frobenius diff = 0.447165
#
#
#         780 sweeps complete,
#         IC = 3.557246,
#         relative Frobenius diff = 0.604235
#
#
#         790 sweeps complete,
#         IC = 3.108481,
#         relative Frobenius diff = 0.516122
#
#
#         800 sweeps complete,
#         IC = 3.502790,
#         relative Frobenius diff = 0.476907
#
#
#         810 sweeps complete,
#         IC = 3.105902,
#         relative Frobenius diff = 0.692781
#
#
#         820 sweeps complete,
#         IC = 3.563026,
#         relative Frobenius diff = 0.987872
#
#
#         830 sweeps complete,
#         IC = 3.429696,
#         relative Frobenius diff = 0.600447
#
#
#         840 sweeps complete,
#         IC = 3.719813,
#         relative Frobenius diff = 0.985569
#
#
#         850 sweeps complete,
#         IC = 3.330886,
#         relative Frobenius diff = 0.457498
#
#
#         860 sweeps complete,
#         IC = 3.417289,
#         relative Frobenius diff = 0.477225
#
#
#         870 sweeps complete,
#         IC = 3.606663,
#         relative Frobenius diff = 0.691905
#
#
#         880 sweeps complete,
#         IC = 3.412777,
#         relative Frobenius diff = 0.366594
#
#
#         890 sweeps complete,
#         IC = 3.438291,
#         relative Frobenius diff = 0.349888
#
#
#         900 sweeps complete,
#         IC = 3.518435,
#         relative Frobenius diff = 0.579310
#
#
#         910 sweeps complete,
#         IC = 3.807972,
#         relative Frobenius diff = 0.333836
#
#
#         920 sweeps complete,
#         IC = 3.532318,
#         relative Frobenius diff = 0.401236
#
#
#         930 sweeps complete,
#         IC = 3.426403,
#         relative Frobenius diff = 0.577415
#
#
#         940 sweeps complete,
#         IC = 3.390089,
#         relative Frobenius diff = 0.360450
#
#
#         950 sweeps complete,
#         IC = 3.644766,
#         relative Frobenius diff = 0.787820
#
#
#         960 sweeps complete,
#         IC = 3.843926,
#         relative Frobenius diff = 0.431568
#
#
#         970 sweeps complete,
#         IC = 3.618449,
#         relative Frobenius diff = 0.752888
#
#
#         980 sweeps complete,
#         IC = 3.391424,
#         relative Frobenius diff = 0.620263
#
#
#         990 sweeps complete,
#         IC = 3.142320,
#         relative Frobenius diff = 0.561382
#
#
#         1000 sweeps complete,
#         IC = 3.357883,
#         relative Frobenius diff = 0.457717
